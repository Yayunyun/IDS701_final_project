# %% [markdown]
# # Merge `drug price data` with `patent_data`

# %%
# import module
import numpy as np
import pandas as pd

# %%
# read patent data with drugs that expired in 2019
patent_2019 = pd.read_excel('patent_expired_2019.xlsx')
patent_2019.head(3)
# Out:
#          INGREDIENT_STRING DOSAGE_FORM      ROUTE TRADE_NAME APPL_TYPE  \
# 0                MINOXIDIL      TABLET       ORAL    LONITEN         N
# 1                MINOXIDIL      TABLET       ORAL    LONITEN         N
# 2  RITODRINE HYDROCHLORIDE  INJECTABLE  INJECTION    YUTOPAR         N
#
#    APPL_NO  PRODUCT_NO PATENT_NO EXPIRE_DATE PE_EXTENSION_FLAG  \
# 0    18154           1   3461461  1985-05-07                 N
# 1    18154           3   3461461  1985-05-07                 N
# 2    18580           1   3410944  1985-11-12                 N
#
#   PE_EXTENSION_DATE DRUG_SUBSTANCE_FLAG DRUG_PRODUCT_FLAG USE_CODE  \
# 0        05/07/1985                   N                 N      NaN
# 1        05/07/1985                   N                 N      NaN
# 2        11/12/1985                   N                 N      NaN
#
#   DELIST_FLAG SUBMISSION_DATE
# 0           N             NaN
# 1           N             NaN
# 2           N             NaN

# %%
# get a list of unique patent names
unique_names  = patent_2019.TRADE_NAME.unique()

# %%
# read drug price data
df = pd.read_csv('drug_data.csv')
df.head(3)
# Out:
#                        Brnd_Name             Gnrc_Name  Tot_Mftr  \
# 0       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 1       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 2  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
#
#          Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0          Overall        217938.04          1014318.0         8595.0
# 1  Owen Mumford Us        217938.04          1014318.0         8595.0
# 2          Overall        402124.68          1850703.0        15403.0
#
#    Tot_Benes_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 0          3025.0                         0.216105              25.356375
# 1          3025.0                         0.216105              25.356375
# 2          5967.0                         0.217359              26.106906
#
#    ...  Tot_Spndng_2021  Tot_Dsg_Unts_2021  Tot_Clms_2021  Tot_Benes_2021  \
# 0  ...        102280.76           459384.0           3708          1313.0
# 1  ...        102280.76           459384.0           3708          1313.0
# 2  ...        131927.33           566872.0           4564          1766.0
#
#    Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  Avg_Spnd_Per_Clm_2021  \
# 0                         0.223001              27.583808
# 1                         0.223001              27.583808
# 2                         0.232812              28.906076
#
#    Avg_Spnd_Per_Bene_2021  Outlier_Flag_2021  Chg_Avg_Spnd_Per_Dsg_Unt_20_21  \
# 0               77.898522                  0                        0.024346
# 1               77.898522                  0                        0.024346
# 2               74.704037                  0                        0.159124
#
#    CAGR_Avg_Spnd_Per_Dsg_Unt_17_21
# 0                         0.007885
# 1                         0.007885
# 2                         0.017317
#
# [3 rows x 46 columns]

# %%
# turn both generic name in the price data and the unique patent name all into upper class for merging
df1 = df.copy()
unique_names = [i.upper() for i in unique_names] # unique patent expired in 2019
df1["Brnd_Name"] = df1["Brnd_Name"].str.upper()

# %%
# merge on 'Brnd Name' and 'Trade Name'
merge_name = []
for name in df1["Brnd_Name"]:
    for unique_patent in unique_names:
        if (name in unique_patent) or (unique_patent in name):
            merge_name.append(name)
            break
        else:
            pass

# %%
merge_name = set(merge_name)
merge_df = df1[df1['Brnd_Name'].isin(merge_name)]
merge_df
# Out:
#               Brnd_Name                     Gnrc_Name  Tot_Mftr  \
# 20              ABELCET  Amphotericin B Lipid Complex         1
# 21              ABELCET  Amphotericin B Lipid Complex         1
# 22              ABILIFY                  Aripiprazole         1
# 23              ABILIFY                  Aripiprazole         1
# 24     ABILIFY MAINTENA                  Aripiprazole         1
# ...                 ...                           ...       ...
# 13746             ZYVOX                     Linezolid         1
# 13747             ZYVOX                     Linezolid         1
# 13748             ZYVOX      Linezolid In Dextrose 5%         2
# 13749             ZYVOX      Linezolid In Dextrose 5%         1
# 13750             ZYVOX      Linezolid In Dextrose 5%         1
#
#              Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 20             Overall     6.756950e+05          68490.000          420.0
# 21     Leadiant Biosci     6.756950e+05          68490.000          420.0
# 22             Overall     3.775740e+07        1158482.500        32241.0
# 23      Otsuka America     3.775740e+07        1158482.500        32241.0
# 24             Overall     2.618508e+08         138042.611       137385.0
# ...                ...              ...                ...            ...
# 13746          Overall     1.479765e+06          15702.000          393.0
# 13747  Pharmaci/Pfizer     1.479765e+06          15702.000          393.0
# 13748          Overall     3.076534e+05        1158228.000          401.0
# 13749  Pharmaci/Pfizer     2.325290e+05         867822.000          313.0
# 13750  Phar-Prep/Pfize     7.512445e+04         290406.000           88.0
#
#        Tot_Benes_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 20              137.0                         9.865601            1608.797691
# 21              137.0                         9.865601            1608.797691
# 22             6955.0                        32.723650            1171.099019
# 23             6955.0                        32.723650            1171.099019
# 24            19543.0                      1896.963569            1905.963555
# ...               ...                              ...                    ...
# 13746           330.0                       161.816476            3765.304707
# 13747           330.0                       161.816476            3765.304707
# 13748           164.0                         0.271663             767.215536
# 13749           126.0                         0.275311             742.904089
# 13750            44.0                         0.258688             853.686932
#
#        ...  Tot_Spndng_2021  Tot_Dsg_Unts_2021  Tot_Clms_2021  Tot_Benes_2021  \
# 20     ...     5.045453e+05           97200.00            697           199.0
# 21     ...     5.045453e+05           97200.00            697           199.0
# 22     ...     2.048485e+07          633899.00          15261          2174.0
# 23     ...     2.048485e+07          633899.00          15261          2174.0
# 24     ...     4.994291e+08          210840.18         208784         26393.0
# ...    ...              ...                ...            ...             ...
# 13746  ...     6.959061e+04            1255.00             43            34.0
# 13747  ...     6.959061e+04            1255.00             43            34.0
# 13748  ...     4.877609e+04          298817.00            159            56.0
# 13749  ...     3.924177e+04          239417.00            122            48.0
# 13750  ...     9.534320e+03           59400.00             37             NaN
#
#        Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  Avg_Spnd_Per_Clm_2021  \
# 20                            5.190796             723.881392
# 21                            5.190796             723.881392
# 22                           32.656164            1342.300713
# 23                           32.656164            1342.300713
# 24                         2368.508428            2392.085174
# ...                                ...                    ...
# 13746                        55.450685            1618.386279
# 13747                        55.450685            1618.386279
# 13748                         0.163115             306.767862
# 13749                         0.163906             321.653852
# 13750                         0.160510             257.684324
#
#        Avg_Spnd_Per_Bene_2021  Outlier_Flag_2021  \
# 20                2535.403668                  0
# 21                2535.403668                  0
# 22                9422.654637                  0
# 23                9422.654637                  0
# 24               18922.786757                  0
# ...                       ...                ...
# 13746             2046.782647                  1
# 13747             2046.782647                  1
# 13748              871.001607                  0
# 13749              817.536875                  0
# 13750                     NaN                  0
#
#        Chg_Avg_Spnd_Per_Dsg_Unt_20_21  CAGR_Avg_Spnd_Per_Dsg_Unt_17_21
# 20                           0.011610                        -0.148318
# 21                           0.011610                        -0.148318
# 22                          -0.051700                        -0.000516
# 23                          -0.051700                        -0.000516
# 24                           0.050991                         0.057071
# ...                               ...                              ...
# 13746                       -0.650784                        -0.234895
# 13747                       -0.650784                        -0.234895
# 13748                       -0.004769                        -0.119729
# 13749                        0.001126                        -0.121599
# 13750                       -0.022745                        -0.112472
#
# [2946 rows x 46 columns]

# %%
# drop drug with multiple manufactuere, i.e. drug with "Mftr == Overall && "Tot_Mftr >= 2""
drop_names = merge_df[(merge_df.Mftr_Name == 'Overall') & (merge_df.Tot_Mftr >=2)].Brnd_Name.unique()
merge_df = merge_df[merge_df.Brnd_Name.isin(drop_names) == False]

# %%
# drop 'Mftr_Name' == "Overall" since it's an average of all that generic drug
merge_df2 = merge_df[merge_df.Mftr_Name != 'Overall']

# %%
# check how many unic drug
merge_df2.Brnd_Name.unique().shape
# Out:
# (1035,)

# %%
# check for number of unique drug after dropping missing values 
merge_df2.dropna().Brnd_Name.unique().shape
# Out:
# (826,)

# %%
merge_df3 = merge_df2.dropna()

# %%
merge_df3.reset_index(inplace = True, drop = True)

# %%
merge_df3.to_csv('merged_price_patent.csv')

# %%
# avg_2017 = merge_df3['Avg_Spnd_Per_Dsg_Unt_Wghtd_2017'].mean()
# avg_2018 = merge_df3['Avg_Spnd_Per_Dsg_Unt_Wghtd_2018'].mean()
# avg_2019 = merge_df3['Avg_Spnd_Per_Dsg_Unt_Wghtd_2019'].mean()
# avg_2020 = merge_df3['Avg_Spnd_Per_Dsg_Unt_Wghtd_2020'].mean()
# avg_2021 = merge_df3['Avg_Spnd_Per_Dsg_Unt_Wghtd_2021'].mean()

# %%
import matplotlib.pyplot as plt

# %%
df_control = pd.read_csv('data/control_price_patent.csv', index_col=False)
avg_20172 = df_control['Avg_Spnd_Per_Dsg_Unt_Wghtd_2017'].mean()
avg_20182 = df_control['Avg_Spnd_Per_Dsg_Unt_Wghtd_2018'].mean()
avg_20192 = df_control['Avg_Spnd_Per_Dsg_Unt_Wghtd_2019'].mean()
avg_20202 = df_control['Avg_Spnd_Per_Dsg_Unt_Wghtd_2020'].mean()
avg_20212 = df_control['Avg_Spnd_Per_Dsg_Unt_Wghtd_2021'].mean()

# %%
x = [2017, 2018, 2019, 2020, 2021]
y = [avg_2017, avg_2018, avg_2019, avg_2020, avg_2021]
y2 = [avg_20172, avg_20182, avg_20192, avg_20202, avg_20212]
plt.plot(x, y, marker = 'o', label = "treatment")
plt.plot(x, y2, marker = 'o', label = 'control')
plt.axvline(x = 2019, color = 'g', linestyle = '--')

plt.xlabel('Year')
plt.xticks([2017, 2018, 2019, 2020, 2021])
plt.ylabel("Average drug price per dosage unit(USD)")
plt.legend()
plt.title('Average drug price v.s. year')
# Out:
# Text(0.5, 1.0, 'Average drug price v.s. year')
