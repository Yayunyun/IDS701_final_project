# %%
import pandas as pd
import numpy as np

# %%
# read file
df = pd.read_csv('drug_data.csv')
df.head()
# Out:
#                        Brnd_Name             Gnrc_Name  Tot_Mftr  \
# 0       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 1       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 2  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 3  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 4                       Abacavir      Abacavir Sulfate         7
#
#          Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0          Overall        217938.04          1014318.0         8595.0
# 1  Owen Mumford Us        217938.04          1014318.0         8595.0
# 2          Overall        402124.68          1850703.0        15403.0
# 3  Owen Mumford Us        402124.68          1850703.0        15403.0
# 4          Overall      13386250.08          3189707.0        48283.0
#
#    Tot_Benes_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 0          3025.0                         0.216105              25.356375
# ...

# %%
# drop Mftr_Name(Manufaturer name) == overall because overall means how many different manufacturers are making this drug
df = [df['Mftr_Name'] != 'Overall']
df.head()
# Out:
#                        Brnd_Name             Gnrc_Name  Tot_Mftr  \
# 1       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 3  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 5                       Abacavir      Abacavir Sulfate         1
# 6                       Abacavir      Abacavir Sulfate         1
# 7                       Abacavir      Abacavir Sulfate         1
#
#          Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 1  Owen Mumford Us        217938.04          1014318.0         8595.0
# 3  Owen Mumford Us        402124.68          1850703.0        15403.0
# 5  Cipla USA, Inc.              NaN                NaN            NaN
# 6  Major Pharmaceu         13130.04             2832.0           55.0
# 7   Strides Pharma        588466.20           125413.0         2017.0
#
#    Tot_Benes_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 1          3025.0                         0.216105              25.356375
# ...

# %%
df.shape
# Out:
# (13751, 46)

# %%
df['matching'] = df.apply(lambda x: x.col1 == x.col3 == x.col4, axis=1)
# Out:
# Overall             3566
# Mylan                240
# Teva USA             236
# Amneal Pharmace      222
# Sandoz               221
#                     ...
# Gsms, Inc.*            1
# Clover Pharmace        1
# Ironshore Pharm        1
# Clarus Therapeu        1
# Eli Lilly & Co.*       1
# Name: Mftr_Name, Length: 914, dtype: int64
